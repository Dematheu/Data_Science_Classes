# %%
# Formação Cientista de Dados - Fernando Amaral e Jones Granatyr
# Igraph

# %%
# Importação das bibliotecas
from igraph import Graph
from igraph import plot

# %%
# Criação de um gráfico direcionado com pesos entre as arestas
grafo = Graph(edges = [(0,2),(0,1),(1,4),(1,5),(2,3),(6,7),(3,7),(4,7),(5,6)],
                       directed = True)
grafo.vs['label'] = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
grafo.es['weight'] = [2,1,2,1,2,1,3,1]

# %%
# Visualização dos resultados
plot(grafo, bbox = (0,0,300,300), edge_label = grafo.es['weight'])

# %%
# Menor caminho entre A - H (retorna os vértices)
caminho_vertice = grafo.get_shortest_paths(0,7, output = 'vpath')
caminho_vertice
# Out:
# [[0, 1, 4, 7]]

# %%
# Retorna as arestas que ligam os dois vértices
caminho_aresta = grafo.get_shortest_paths(0,7, output = 'epath')
caminho_aresta
# Out:
# [[1, 2, 7]]

# %%
# Mostra o ID dos vértices que fazem parte do caminho
caminho_aresta_id = []
for n in caminho_aresta[0]:
    caminho_aresta_id.append(n)
caminho_aresta_id
# Out:
# [1, 2, 7]

# %%
# Mostra o nome dos vértices que fazem parte do caminho
caminho_nome_vertices = []
for n in caminho_vertice[0]:
    print(f"Adicionando: {grafo.vs[n]['label']}")
    caminho_nome_vertices.append(grafo.vs[n]['label'])
caminho_nome_vertices
# Out:
# Adicionando: A
# Adicionando: B
# Adicionando: E
# Adicionando: H
# ['A', 'B', 'E', 'H']

# %%
# Colorir os vértices do caminho
for v in grafo.vs:
    print(v)
    if v['label'] in caminho_nome_vertices:
        v['color'] = 'green'
    else:
        v['color'] = 'gray'
# Out:
# igraph.Vertex(<igraph.Graph object at 0x0000020DD0B35140>, 0, {'label': 'A', 'color': 'green'})
# igraph.Vertex(<igraph.Graph object at 0x0000020DD0B35140>, 1, {'label': 'B', 'color': 'green'})
# igraph.Vertex(<igraph.Graph object at 0x0000020DD0B35140>, 2, {'label': 'C', 'color': 'grey'})
# igraph.Vertex(<igraph.Graph object at 0x0000020DD0B35140>, 3, {'label': 'D', 'color': 'grey'})
# igraph.Vertex(<igraph.Graph object at 0x0000020DD0B35140>, 4, {'label': 'E', 'color': 'green'})
# igraph.Vertex(<igraph.Graph object at 0x0000020DD0B35140>, 5, {'label': 'F', 'color': 'grey'})
# igraph.Vertex(<igraph.Graph object at 0x0000020DD0B35140>, 6, {'label': 'G', 'color': 'grey'})
# igraph.Vertex(<igraph.Graph object at 0x0000020DD0B35140>, 7, {'label': 'H', 'color': 'green'})

# %%
# Colorir as arestas do caminho
for e in grafo.es:
    print(e)
    if e.index in caminho_aresta_id:
        e['color'] = 'green'
    else:
        e['color'] = 'gray'
# Out:
# igraph.Edge(<igraph.Graph object at 0x0000020DD0B35140>, 0, {'weight': 2, 'color': 'gray'})
# igraph.Edge(<igraph.Graph object at 0x0000020DD0B35140>, 1, {'weight': 1, 'color': 'green'})
# igraph.Edge(<igraph.Graph object at 0x0000020DD0B35140>, 2, {'weight': 2, 'color': 'green'})
# igraph.Edge(<igraph.Graph object at 0x0000020DD0B35140>, 3, {'weight': 1, 'color': 'gray'})
# igraph.Edge(<igraph.Graph object at 0x0000020DD0B35140>, 4, {'weight': 2, 'color': 'gray'})
# igraph.Edge(<igraph.Graph object at 0x0000020DD0B35140>, 5, {'weight': 1, 'color': 'gray'})
# igraph.Edge(<igraph.Graph object at 0x0000020DD0B35140>, 6, {'weight': 3, 'color': 'gray'})
# igraph.Edge(<igraph.Graph object at 0x0000020DD0B35140>, 7, {'weight': 1, 'color': 'green'})
# igraph.Edge(<igraph.Graph object at 0x0000020DD0B35140>, 8, {'weight': 2, 'color': 'gray'})

# %%
plot(grafo, bbox=(0,0,300,300))
